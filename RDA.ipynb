# %% [markdown]
# # Reglas de Asociación

# %% [markdown]
# Obtenga reglas de asociación interesantes del conjunto de datos usando el algoritmo “A priori”. Recuerde discretizar las variables numéricas. Genere reglas con diferentes niveles de confianza y soporte. Discuta los resultados. Si considera que debe eliminar variables porque son muy frecuentes y con eso puede recibir más “insights” de la generación de reglas. Hágalo y discútalo.

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Cargar el dataset
file_path = "movies.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Seleccionar las columnas categóricas relevantes
categorical_vars = ["genres", "productionCountry", "originalLanguage"]

# Convertir los valores categóricos en formato adecuado para Apriori
# Separar valores si hay múltiples categorías en una celda
df_apriori = df[categorical_vars].astype(str).apply(lambda x: x.str.split(',')).explode().reset_index()

# Crear una matriz de transacciones (One-Hot Encoding de cada categoría)
df_apriori = pd.get_dummies(df_apriori.set_index("index"))

# Aplicar el algoritmo Apriori con diferentes valores de soporte
min_support_values = [0.01, 0.05, 0.1]
min_confidence_values = [0.6, 0.7, 0.8]

association_results = {}
for min_support in min_support_values:
    # Generar los itemsets frecuentes
    frequent_itemsets = apriori(df_apriori, min_support=min_support, use_colnames=True)
    
    for min_confidence in min_confidence_values:
        # Generar reglas de asociación con diferentes niveles de confianza
        rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
        
        # Almacenar los resultados para comparación
        association_results[(min_support, min_confidence)] = rules

# Mostrar un ejemplo de reglas generadas
for key, rules_df in association_results.items():
    print(f"Reglas de Asociación (min_support={key[0]}, min_confidence={key[1]})")
    print(rules_df.head(), "\n")

# Evaluar si quitar características
# Si hay muchas reglas irrelevantes, podríamos eliminar variables con alta cardinalidad
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 13
#       9 categorical_vars = ["genres", "productionCountry", "originalLanguage"]
#      11 # Convertir los valores categóricos en formato adecuado para Apriori
#      12 # Separar valores si hay múltiples categorías en una celda
# ---> 13 df_apriori = df[categorical_vars].astype(str).apply(lambda x: x.str.split(',')).explode().reset_index()
#      15 # Crear una matriz de transacciones (One-Hot Encoding de cada categoría)
#      16 df_apriori = pd.get_dummies(df_apriori.set_index("index"))
#
# TypeError: DataFrame.explode() missing 1 required positional argument: 'column'

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# Cargar el dataset
file_path = "movies.csv"
df = pd.read_csv(file_path, encoding="ISO-8859-1")

# Seleccionar las columnas categóricas relevantes
categorical_vars = ["genres", "productionCountry", "originalLanguage"]

# Convertir los valores categóricos en formato adecuado para Apriori
# Separar valores si hay múltiples categorías en una celda y explotar cada columna
for col in categorical_vars:
    df[col] = df[col].astype(str).str.split(',')

df_apriori = df.explode(categorical_vars)  # Aplicar explode() correctamente

# Crear una matriz de transacciones (One-Hot Encoding de cada categoría)
df_apriori = pd.get_dummies(df_apriori[categorical_vars])

# Aplicar el algoritmo Apriori con diferentes valores de soporte
min_support_values = [0.01, 0.05, 0.1]
min_confidence_values = [0.6, 0.7, 0.8]

association_results = {}
for min_support in min_support_values:
    # Generar los itemsets frecuentes
    frequent_itemsets = apriori(df_apriori, min_support=min_support, use_colnames=True)
    
    for min_confidence in min_confidence_values:
        # Generar reglas de asociación con diferentes niveles de confianza
        rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
        
        # Almacenar los resultados para comparación
        association_results[(min_support, min_confidence)] = rules

# Mostrar un ejemplo de reglas generadas
for key, rules_df in association_results.items():
    print(f"Reglas de Asociación (min_support={key[0]}, min_confidence={key[1]})")
    print(rules_df.head(), "\n")

# Evaluar si quitar características
# Si hay muchas reglas irrelevantes, podríamos eliminar variables con alta cardinalidad
# Out:
# Reglas de Asociación (min_support=0.01, min_confidence=0.6)
#                 antecedents                                   consequents  \
# 0  (genres_Action|Thriller)                         (originalLanguage_en)
# 1           (genres_Comedy)  (productionCountry_United States of America)
# 2           (genres_Comedy)                         (originalLanguage_en)
# 3     (genres_Comedy|Drama)                         (originalLanguage_en)
# 4   (genres_Comedy|Romance)                         (originalLanguage_en)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0              0.0121              0.7772   0.0106    0.876033  1.127166
# 1              0.0440              0.4971   0.0268    0.609091  1.225288
# 2              0.0440              0.7772   0.0318    0.722727  0.929912
# 3              0.0140              0.7772   0.0102    0.728571  0.937431
# 4              0.0201              0.7772   0.0164    0.815920  1.049820
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.001196    1.797253       0.114201  0.013612   0.443595
# 1               1.0  0.004928    1.286488       0.192328  0.052110   0.222690
# 2               1.0 -0.002397    0.803541      -0.073079  0.040284  -0.244492
# 3               1.0 -0.000681    0.820842      -0.063401  0.013060  -0.218261
# 4               1.0  0.000778    1.210346       0.048430  0.021001   0.173790
#
#    kulczynski
# 0    0.444836
# 1    0.331502
# 2    0.381822
# 3    0.370848
# 4    0.418511
#
# Reglas de Asociación (min_support=0.01, min_confidence=0.7)
#                 antecedents            consequents  antecedent support  \
# 0  (genres_Action|Thriller)  (originalLanguage_en)              0.0121
# 1           (genres_Comedy)  (originalLanguage_en)              0.0440
# 2     (genres_Comedy|Drama)  (originalLanguage_en)              0.0140
# 3   (genres_Comedy|Romance)  (originalLanguage_en)              0.0201
# 4      (genres_Documentary)  (originalLanguage_en)              0.0194
#
#    consequent support  support  confidence      lift  representativity  \
# 0              0.7772   0.0106    0.876033  1.127166               1.0
# 1              0.7772   0.0318    0.722727  0.929912               1.0
# 2              0.7772   0.0102    0.728571  0.937431               1.0
# 3              0.7772   0.0164    0.815920  1.049820               1.0
# 4              0.7772   0.0172    0.886598  1.140759               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.001196    1.797253       0.114201  0.013612   0.443595    0.444836
# 1 -0.002397    0.803541      -0.073079  0.040284  -0.244492    0.381822
# 2 -0.000681    0.820842      -0.063401  0.013060  -0.218261    0.370848
# 3  0.000778    1.210346       0.048430  0.021001   0.173790    0.418511
# 4  0.002122    1.964691       0.125832  0.022068   0.491014    0.454364
#
# Reglas de Asociación (min_support=0.01, min_confidence=0.8)
#                 antecedents            consequents  antecedent support  \
# 0  (genres_Action|Thriller)  (originalLanguage_en)              0.0121
# 1   (genres_Comedy|Romance)  (originalLanguage_en)              0.0201
# 2      (genres_Documentary)  (originalLanguage_en)              0.0194
# 3           (genres_Horror)  (originalLanguage_en)              0.0230
# 4  (genres_Horror|Thriller)  (originalLanguage_en)              0.0205
#
#    consequent support  support  confidence      lift  representativity  \
# 0              0.7772   0.0106    0.876033  1.127166               1.0
# 1              0.7772   0.0164    0.815920  1.049820               1.0
# 2              0.7772   0.0172    0.886598  1.140759               1.0
# 3              0.7772   0.0196    0.852174  1.096467               1.0
# 4              0.7772   0.0193    0.941463  1.211353               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.001196    1.797253       0.114201  0.013612   0.443595    0.444836
# 1  0.000778    1.210346       0.048430  0.021001   0.173790    0.418511
# 2  0.002122    1.964691       0.125832  0.022068   0.491014    0.454364
# 3  0.001724    1.507176       0.090051  0.025109   0.336508    0.438696
# 4  0.003367    3.806167       0.178128  0.024794   0.737268    0.483148
#
# Reglas de Asociación (min_support=0.05, min_confidence=0.6)
#                                     antecedents  \
# 0                     (productionCountry_Japan)
# 1                         (originalLanguage_ja)
# 2                         (originalLanguage_en)
# 3  (productionCountry_United States of America)
#
#                                     consequents  antecedent support  \
# 0                         (originalLanguage_ja)              0.0613
# 1                     (productionCountry_Japan)              0.0644
# 2  (productionCountry_United States of America)              0.7772
# 3                         (originalLanguage_en)              0.4971
#
#    consequent support  support  confidence       lift  representativity  \
# 0              0.0644   0.0608    0.991843  15.401295               1.0
# 1              0.0613   0.0608    0.944099  15.401295               1.0
# 2              0.4971   0.4962    0.638446   1.284341               1.0
# 3              0.7772   0.4962    0.998189   1.284341               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.056852  114.704560       0.996133  0.936826   0.991282    0.967971
# 1  0.056852   16.792300       0.999434  0.936826   0.940449    0.967971
# 2  0.109854    1.390939       0.993673  0.637707   0.281061    0.818318
# 3  0.109854  123.059867       0.440227  0.637707   0.991874    0.818318
#
# Reglas de Asociación (min_support=0.05, min_confidence=0.7)
#                                     antecedents                consequents  \
# 0                     (productionCountry_Japan)      (originalLanguage_ja)
# 1                         (originalLanguage_ja)  (productionCountry_Japan)
# 2  (productionCountry_United States of America)      (originalLanguage_en)
#
#    antecedent support  consequent support  support  confidence       lift  \
# 0              0.0613              0.0644   0.0608    0.991843  15.401295
# 1              0.0644              0.0613   0.0608    0.944099  15.401295
# 2              0.4971              0.7772   0.4962    0.998189   1.284341
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.056852  114.704560       0.996133  0.936826   0.991282
# 1               1.0  0.056852   16.792300       0.999434  0.936826   0.940449
# 2               1.0  0.109854  123.059867       0.440227  0.637707   0.991874
#
#    kulczynski
# 0    0.967971
# 1    0.967971
# 2    0.818318
#
# Reglas de Asociación (min_support=0.05, min_confidence=0.8)
#                                     antecedents                consequents  \
# 0                     (productionCountry_Japan)      (originalLanguage_ja)
# 1                         (originalLanguage_ja)  (productionCountry_Japan)
# 2  (productionCountry_United States of America)      (originalLanguage_en)
#
#    antecedent support  consequent support  support  confidence       lift  \
# 0              0.0613              0.0644   0.0608    0.991843  15.401295
# 1              0.0644              0.0613   0.0608    0.944099  15.401295
# 2              0.4971              0.7772   0.4962    0.998189   1.284341
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.056852  114.704560       0.996133  0.936826   0.991282
# 1               1.0  0.056852   16.792300       0.999434  0.936826   0.940449
# 2               1.0  0.109854  123.059867       0.440227  0.637707   0.991874
#
#    kulczynski
# 0    0.967971
# 1    0.967971
# 2    0.818318
#
# Reglas de Asociación (min_support=0.1, min_confidence=0.6)
#                                     antecedents  \
# 0                         (originalLanguage_en)
# 1  (productionCountry_United States of America)
#
#                                     consequents  antecedent support  \
# 0  (productionCountry_United States of America)              0.7772
# 1                         (originalLanguage_en)              0.4971
#
#    consequent support  support  confidence      lift  representativity  \
# 0              0.4971   0.4962    0.638446  1.284341               1.0
# 1              0.7772   0.4962    0.998189  1.284341               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.109854    1.390939       0.993673  0.637707   0.281061    0.818318
# 1  0.109854  123.059867       0.440227  0.637707   0.991874    0.818318
#
# Reglas de Asociación (min_support=0.1, min_confidence=0.7)
#                                     antecedents            consequents  \
# 0  (productionCountry_United States of America)  (originalLanguage_en)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0              0.4971              0.7772   0.4962    0.998189  1.284341
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.109854  123.059867       0.440227  0.637707   0.991874
#
#    kulczynski
# 0    0.818318
#
# Reglas de Asociación (min_support=0.1, min_confidence=0.8)
#                                     antecedents            consequents  \
# 0  (productionCountry_United States of America)  (originalLanguage_en)
#
#    antecedent support  consequent support  support  confidence      lift  \
# 0              0.4971              0.7772   0.4962    0.998189  1.284341
#
#    representativity  leverage  conviction  zhangs_metric   jaccard  certainty  \
# 0               1.0  0.109854  123.059867       0.440227  0.637707   0.991874
#
#    kulczynski
# 0    0.818318
